# %%
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))
print("Você digitou os números", num1, "e", num2)
soma = num1 + num2
subtracao = num1 - num2
multiplicacao = num1 * num2
divisao = num1 / num2

print("Soma:", soma)
print("Subtração:", subtracao)
print("Multiplicação:", multiplicacao)
print("Divisão:", divisao)
# Out:
# Digite o primeiro número: 24
# Digite o segundo número: 26
# Você digitou os números 24.0 e 26.0
# Soma: 50.0
# Subtração: -2.0
# Multiplicação: 624.0
# Divisão: 0.9230769230769231

# %%
if soma > 50:
    print("A soma é maior que 50.")
elif soma == 50:
    print("A soma é igual a 50.")
else:
    print("A soma é menor que 50.")
# Out:
# A soma é igual a 50.
